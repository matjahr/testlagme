# %%
import yfinance as yf

# Extraer datos de Tesla
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-12-01')

# Restablecer el índice
tesla_data.reset_index(inplace=True)

# Mostrar las primeras cinco filas
print(tesla_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                  TSLA       TSLA       TSLA       TSLA       TSLA
# 0      2020-01-02  28.684000  28.684000  28.713333  28.114000  28.299999
# 1      2020-01-03  29.534000  29.534000  30.266666  29.128000  29.366667
# 2      2020-01-06  30.102667  30.102667  30.104000  29.333332  29.364668
# 3      2020-01-07  31.270666  31.270666  31.441999  30.224001  30.760000
# 4      2020-01-08  32.809334  32.809334  33.232666  31.215334  31.580000
#
# Price      Volume
# Ticker       TSLA
# 0       142981500
# 1       266677500
# 2       151995000
# 3       268231500
# 4       467164500

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de los datos de ingresos de Tesla
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"

# Realizar la solicitud a la página web
response = requests.get(url)

# Analizar el contenido HTML
soup = BeautifulSoup(response.content, "html.parser")

# Buscar la tabla que contiene los datos de ingresos
revenue_table = soup.find("table")

# Extraer datos de la tabla
data = []
for row in revenue_table.find_all("tr")[1:]:  # Omitir la fila del encabezado
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]
    if len(cols) == 2:  # Asegurarse de que la fila tiene dos columnas (fecha e ingresos)
        data.append(cols)

# Crear un DataFrame
tesla_revenue = pd.DataFrame(data, columns=["Date", "Revenue"])

# Eliminar valores no numéricos y convertir a un formato limpio
tesla_revenue["Revenue"] = tesla_revenue["Revenue"].str.replace(",", "").str.replace("$", "")
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]
tesla_revenue["Revenue"] = pd.to_numeric(tesla_revenue["Revenue"])
tesla_revenue["Date"] = pd.to_datetime(tesla_revenue["Date"])

# Mostrar las últimas cinco filas
print(tesla_revenue.tail())
# Out:
#          Date  Revenue
# 8  2013-01-01     2013
# 9  2012-01-01      413
# 10 2011-01-01      204
# 11 2010-01-01      117
# 12 2009-01-01      112

# %%
import yfinance as yf

# Extraer datos de GameStop
gme_data = yf.download('GME', start='2020-01-01', end='2023-12-01')

# Restablecer el índice
gme_data.reset_index(inplace=True)

# Mostrar las primeras cinco filas
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date Adj Close   Close    High     Low    Open    Volume
# Ticker                  GME     GME     GME     GME     GME       GME
# 0      2020-01-02    1.5775  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03    1.4700  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06    1.4625  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07    1.3800  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08    1.4300  1.4300  1.4625  1.3525  1.3725  22517600

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de los datos de ingresos de GME
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"

# Realizar la solicitud a la página web
response = requests.get(url)

# Analizar el contenido HTML
soup = BeautifulSoup(response.content, "html.parser")

# Buscar la tabla que contiene los datos de ingresos
revenue_table = soup.find("table")

# Extraer datos de la tabla
data = []
for row in revenue_table.find_all("tr")[1:]:  # Omitir la fila del encabezado
    cols = row.find_all("td")
    cols = [col.text.strip() for col in cols]
    if len(cols) == 2:  # Asegurarse de que la fila tiene dos columnas (fecha e ingresos)
        data.append(cols)

# Crear un DataFrame
gme_revenue = pd.DataFrame(data, columns=["Date", "Revenue"])

# Eliminar valores no numéricos y convertir a un formato limpio
gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(",", "").str.replace("$", "")
gme_revenue = gme_revenue[gme_revenue["Revenue"] != ""]
gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"])
gme_revenue["Date"] = pd.to_datetime(gme_revenue["Date"])

# Mostrar las últimas cinco filas
print(gme_revenue.tail())
# Out:
#          Date  Revenue
# 11 2009-01-01     8806
# 12 2008-01-01     7094
# 13 2007-01-01     5319
# 14 2006-01-01     3092
# 15 2005-01-01     1843

# %%
import plotly.graph_objects as go

# Función para representar gráficamente los datos
def make_graph(data, title):
    fig = go.Figure()
    # Agregar línea de tiempo de los precios de cierre
    fig.add_trace(go.Scatter(x=data['Date'], y=data['Close'], mode='lines', name='Close Price'))
    fig.update_layout(title=title, xaxis_title='Date', yaxis_title='Close Price (USD)', template='plotly_dark')
    fig.show()

# Representar gráficamente los datos de Tesla
make_graph(tesla_data, "Tesla Stock Price Over Time")

# %%
# Representar gráficamente los datos de GameStop
make_graph(gme_data, "GameStop Stock Price Over Time")
